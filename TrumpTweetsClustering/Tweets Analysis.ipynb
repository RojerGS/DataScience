# %%
# General:
import pandas as pd     # To handle data
import numpy as np      # For number computing
import json
import nltk
nltk.download('stopwords')
import re as re
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# Create a pandas dataframe
with open(r'C:\Users\Dieuwke\Documents\MSc\MSc AM\Mathematical Data Science\Trumps Tweet Analysis Project\DataScience\TrumpTweetsClustering\Data\TrumpTweets2018.json') as json_file:
    jdata = json.load(json_file)
    
data = pd.DataFrame(data=jdata)

data.drop(["created_at", "favorite_count", "id_str", "retweet_count", "source"], axis=1, inplace=True)
data.columns = ["is_retweet","text"]
data = data[data.is_retweet == False]
data.drop(["is_retweet"], axis=1, inplace=True)

#Create data file with original tweets (without retweets)
data_original = data.reset_index()
data_original.drop(["index"], axis = 1, inplace=True)
data_original.to_csv('data_original.csv')
display(data_original.head(100))

#Cleaning of tweets

from nltk.corpus import stopwords
stop = stopwords.words('english')

data["text"] = data["text"].str.replace("(@[A-Za-z]+)|([^A-Za-z \t])|(\w+:\/\/\S+)"," ")
data["text"] = data["text"].str.lower().str.split()
data["text"] = data["text"].apply(lambda x: ' '.join([word for word in x if word not in stop]))
data["text"] = data["text"].str.split()
display(data.head(10))
data["text"] = data["text"].apply(lambda x: [stemmer.stem(y) for y in x])
data = data.reset_index()
data.drop(["index"], axis = 1, inplace=True)
display(data.head(100))

data.to_csv('data_clean_new.csv')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dieuwke\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                  text
# 0   President and Mrs. Obama built/has a ten foot ...
# 1   Great work by my Administration over the holid...
# 2   Veterans on President Trump’s handling of Bord...
# 3   “It turns out to be true now, that the Departm...
# 4   “Absolutely nothing” (on Russian Collusion). K...
# 5   2018 is being called “THE YEAR OF THE WORKER” ...
# 6   For those that naively ask why didn’t the Repu...
# 7   ...children in question were very sick before ...
# 8   Any deaths of children or others at the Border...
# 9   Just had a long and very good call with Presid...
# 10  I am in the White House waiting for the Democr...
# 11  The Mueller Angry Democrats recently deleted a...
# 12  Thank you to Sean Parnell for the nice comment...
# 13  .....Honduras, Guatemala and El Salvador are d...
# 14  .....close the Southern Border. Bring our car ...
# 15  ....The United States looses soooo much money ...
# 16  We will be forced to close the Southern Border...
# 17  CNN &amp; others within the Fake News Universe...
# 18  This isn’t about the Wall, everybody knows tha...
# 19  Brad Blakeman: “The American people understand...
# 20  Brad Blakeman: “The American people understand...
# 21           I totally agree! https://t.co/KO8E3bfWfn
# 22  There is right now a full scale manhunt going ...
# 23  “Border Patrol Agents want the Wall.” Democrat...
# 24  The reason the DACA for Wall deal didn’t get d...
# 25  The Democrats OBSTRUCTION of the desperately n...
# 26  The reason the DACA for Wall deal didn’t get d...
# 27  Have the Democrats finally realized that we de...
# 28  Just returned from visiting our troops in Iraq...
# 29  .@FLOTUS Melania and I were honored to visit o...
# ..                                                ...
# 70  A design of our Steel Slat Barrier which is to...
# 71  Today, it was my honor to sign into law H.R. 7...
# 72  Today, it was my great honor to sign the #Firs...
# 73  I’ve done more damage to ISIS than all recent ...
# 74                The Democrats now own the shutdown!
# 75  General Anthony Tata, author, “Dark Winter.” I...
# 76  There has never been a president who has been ...
# 77  Thank you @SteveDaines for being willing to go...
# 78  Mitch, use the Nuclear Option and get it done!...
# 79  Even President Ronald Reagan tried for 8 years...
# 80  Shutdown today if Democrats do not vote for Bo...
# 81                    House Republican Vote, 217-185.
# 82  The Democrats, whose votes we need in the Sena...
# 83  No matter what happens today in the Senate, Re...
# 84  .....on a Border is only effective in conjunct...
# 85  The Democrats are trying to belittle the conce...
# 86  Senator Mitch McConnell should fight for the W...
# 87  Soon to be Speaker Nancy Pelosi said, last wee...
# 88  Thank you to our GREAT Republican Members of C...
# 89  General Jim Mattis will be retiring, with dist...
# 90  ....equipment. General Mattis was a great help...
# 91  Democrats, it is time to come together and put...
# 92  Farm Bill signing in 15 minutes! #Emmys #TBT h...
# 93  So hard to believe that Lindsey Graham would b...
# 94  Congress just passed the Criminal Justice Refo...
# 95  When I begrudgingly signed the Omnibus Bill, I...
# 96  With so much talk about the Wall, people are l...
# 97  The Democrats, who know Steel Slats (Wall) are...
# 98  ....Russia, Iran, Syria &amp; many others are ...
# 99  Does the USA want to be the Policeman of the M...
#
# [100 rows x 1 columns]
#                                                 text
# 0  [president, mrs, obama, built, ten, foot, wall...
# 1  [great, work, administration, holidays, save, ...
# 2  [veterans, president, trump, handling, border,...
# 3  [turns, true, department, justice, fbi, presid...
# 4  [absolutely, nothing, russian, collusion, kimb...
# 5  [called, year, worker, steve, moore, co, autho...
# 6  [naively, ask, republicans, get, approval, bui...
# 7  [children, question, sick, given, border, patr...
# 8  [deaths, children, others, border, strictly, f...
# 9  [long, good, call, president, xi, china, deal,...
#                                                  text
# 0   [presid, mr, obama, built, ten, foot, wall, ar...
# 1   [great, work, administr, holiday, save, coast,...
# 2   [veteran, presid, trump, handl, border, secur,...
# 3   [turn, true, depart, justic, fbi, presid, obam...
# 4   [absolut, noth, russian, collus, kimberley, st...
# 5   [call, year, worker, steve, moor, co, author, ...
# 6   [naiv, ask, republican, get, approv, build, wa...
# 7   [children, question, sick, given, border, patr...
# 8   [death, children, other, border, strictli, fau...
# 9   [long, good, call, presid, xi, china, deal, mo...
# 10  [white, hous, wait, democrat, come, make, deal...
# 11  [mueller, angri, democrat, recent, delet, appr...
# 12  [thank, sean, parnel, nice, comment, troop, wo...
# 13  [hondura, guatemala, el, salvador, noth, unit,...
# 14  [close, southern, border, bring, car, industri...
# 15  [unit, state, loos, soooo, much, money, trade,...
# 16  [forc, close, southern, border, entir, obstruc...
# 17  [cnn, amp, other, within, fake, news, univers,...
# 18  [wall, everybodi, know, wall, work, perfectli,...
# 19  [brad, blakeman, american, peopl, understand, ...
# 20  [brad, blakeman, american, peopl, understand, ...
# 21                                      [total, agre]
# 22  [right, full, scale, manhunt, go, california, ...
# 23  [border, patrol, agent, want, wall, democrat, ...
# 24  [reason, daca, wall, deal, get, done, ridicul,...
# 25  [democrat, obstruct, desper, need, wall, almos...
# 26  [reason, daca, wall, deal, get, done, ridicul,...
# 27  [democrat, final, realiz, desper, need, border...
# 28  [return, visit, troop, iraq, germani, one, thi...
# 29  [melania, honor, visit, incred, troop, al, asa...
# ..                                                ...
# 70  [design, steel, slat, barrier, total, effect, ...
# 71  [today, honor, sign, law, h, r, counter, weapo...
# 72  [today, great, honor, sign, firststepact, monu...
# 73    [done, damag, isi, recent, presid, even, close]
# 74                               [democrat, shutdown]
# 75  [gener, anthoni, tata, author, dark, winter, t...
# 76  [never, presid, tougher, fair, china, russia, ...
# 77  [thank, will, go, call, nuclear, option, order...
# 78  [mitch, use, nuclear, option, get, done, count...
# 79  [even, presid, ronald, reagan, tri, year, buil...
# 80   [shutdown, today, democrat, vote, border, secur]
# 81                           [hous, republican, vote]
# 82  [democrat, whose, vote, need, senat, probabl, ...
# 83  [matter, happen, today, senat, republican, hou...
# 84  [border, effect, conjunct, wall, properli, des...
# 85  [democrat, tri, belittl, concept, wall, call, ...
# 86  [senat, mitch, mcconnel, fight, wall, border, ...
# 87  [soon, speaker, nanci, pelosi, said, last, wee...
# 88  [thank, great, republican, member, congress, v...
# 89  [gener, jim, matti, retir, distinct, end, febr...
# 90  [equip, gener, matti, great, help, get, alli, ...
# 91  [democrat, time, come, togeth, put, safeti, am...
# 92               [farm, bill, sign, minut, emmi, tbt]
# 93  [hard, believ, lindsey, graham, would, save, s...
# 94  [congress, pass, crimin, justic, reform, bill,...
# 95  [begrudgingli, sign, omnibu, bill, promis, wal...
# 96  [much, talk, wall, peopl, lose, sight, great, ...
# 97  [democrat, know, steel, slat, wall, necessari,...
# 98  [russia, iran, syria, amp, mani, other, happi,...
# 99  [usa, want, policeman, middl, east, get, noth,...
#
# [100 rows x 1 columns]

# %%
print(data_original["text"][1241])
# Out:
# https://t.co/0a25gApyJ6
