# %%
# General:
import pandas as pd     # To handle data
import numpy as np      # For number computing
import json
import nltk
nltk.download('stopwords')
import re as re

# For plotting and visualization:
# from IPython.display import display
# import matplotlib.pyplot as plt
# import seaborn as sns
# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dieuwke\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Create a pandas dataframe
with open(r'C:\Users\Dieuwke\Documents\MSc\MSc AM\Mathematical Data Science\Trumps Tweet Analysis Project\DataScience\TrumpTweetsClustering\Data\TrumpTweets2018.json') as json_file:
    jdata = json.load(json_file)
    
data = pd.DataFrame(data=jdata)

data.drop(["created_at", "favorite_count", "id_str", "retweet_count", "source"], axis=1, inplace=True)
data.columns = ["is_retweet","text"]

display(data.head(10))
# Out:
#   is_retweet                                               text
# 0      False  President and Mrs. Obama built/has a ten foot ...
# 1      False  Great work by my Administration over the holid...
# 2      False  Veterans on President Trump’s handling of Bord...
# 3      False  “It turns out to be true now, that the Departm...
# 4      False  “Absolutely nothing” (on Russian Collusion). K...
# 5      False  2018 is being called “THE YEAR OF THE WORKER” ...
# 6      False  For those that naively ask why didn’t the Repu...
# 7      False  ...children in question were very sick before ...
# 8      False  Any deaths of children or others at the Border...
# 9      False  Just had a long and very good call with Presid...

# %%
#Cleaning of tweets

from nltk.corpus import stopwords
stop = stopwords.words('english')
stop += ['the', 'a', 'an', ''] 

data["text"] = data["text"].str.replace("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ")
data["text"] = data["text"].str.lower().str.split()
data["text"] = data["text"].apply(lambda x: ' '.join([word for word in x if word not in stop]))
data["text"] = data["text"].str.split()

display(data.head(10))
# Out:
#   is_retweet                                               text
# 0      False  [president, mrs, obama, built, ten, foot, wall...
# 1      False  [great, work, administration, holidays, save, ...
# 2      False  [veterans, president, trump, handling, border,...
# 3      False  [turns, true, department, justice, fbi, presid...
# 4      False  [absolutely, nothing, russian, collusion, kimb...
# 5      False  [2018, called, year, worker, steve, moore, co,...
# 6      False  [naively, ask, republicans, get, approval, bui...
# 7      False  [children, question, sick, given, border, patr...
# 8      False  [deaths, children, others, border, strictly, f...
# 9      False  [long, good, call, president, xi, china, deal,...
